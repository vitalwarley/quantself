# %%
import os
import pandas as pd

# %%
strong = pd.read_csv('data/health/strong.csv', delimiter=';', escapechar='\\')

# %%
strong
# Out:
#                      Date Workout Name                     Exercise Name  \
# 0     2020-08-31 12:00:00     Treino A             Bench Press (Barbell)
# 1     2020-08-31 12:00:00     Treino A             Bench Press (Barbell)
# 2     2020-08-31 12:00:00     Treino A             Bench Press (Barbell)
# 3     2020-08-31 12:00:00     Treino A    Incline Bench Press (Dumbbell)
# 4     2020-08-31 12:00:00     Treino A    Incline Bench Press (Dumbbell)
# ...                   ...          ...                               ...
# 7058  2021-03-19 18:11:45     Treino D  Seated Calf Raise (Plate Loaded)
# 7059  2021-03-19 18:11:45     Treino D     Standing Calf Raise (Machine)
# 7060  2021-03-19 18:11:45     Treino D     Standing Calf Raise (Machine)
# 7061  2021-03-19 18:11:45     Treino D     Standing Calf Raise (Machine)
# 7062  2021-03-19 18:11:45     Treino D     Standing Calf Raise (Machine)
#
#       Set Order Weight Weight Unit  Reps  RPE Distance Distance Unit  Seconds  \
# ...

# %%
strong.loc[(strong.Date == 'Dedos. "')]
# Out:
# Empty DataFrame
# Columns: [Date, Workout Name, Exercise Name, Set Order, Weight, Weight Unit, Reps, RPE, Distance, Distance Unit, Seconds, Notes, Workout Notes]
# Index: []

# %%
strong.loc[~strong.Date.str.startswith('20')]
# Out:
#                                                    Date Workout Name  \
# 2291         90s rest entre as pernas. 30s na última. "          NaN
# 4009  Execução mt melhor. Mais confiança. Só preciso...          NaN
#
#      Exercise Name  Set Order Weight Weight Unit  Reps  RPE Distance  \
# 2291           NaN        NaN    NaN         NaN   NaN  NaN      NaN
# 4009           NaN        NaN    NaN         NaN   NaN  NaN      NaN
#
#      Distance Unit  Seconds Notes Workout Notes
# 2291           NaN      NaN   NaN           NaN
# 4009           NaN      NaN   NaN           NaN
